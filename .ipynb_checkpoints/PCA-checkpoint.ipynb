# %%
import matplotlib as mpl
mpl.rcParams["figure.facecolor"] = "white"

mpl.rcParams["axes.facecolor"] = "white"
mpl.rcParams["savefig.facecolor"] = "white"
# %matplotlib inline

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

# %%
from calibration_dataset import Tell1Dataset

class MyDS(Tell1Dataset):
    filename_format = '%Y-%m-%d'
    filename_regex_format = r'\d{4}-\d{2}-\d{2}.csv'

datapath = "../data/calibrations/"
data_list = MyDS.get_filepaths_from_dir(datapath)
mds = MyDS(data_list, read=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:07<00:00,  4.00it/s]

# %%
data = {'hit threshold':mds.dfh.df,'pedestal' : mds.dfp.df,'low threshold': mds.dfl.df}
# Out:
# {'hit threshold':                type  sensor   datetime  Zmod slot_label  mod_nr  mod_type  \
#  2     hit_threshold     0.0 2010-08-16  -175      VL01L   mod_0  VELO_phi
#  5     hit_threshold     0.0 2010-08-18  -175      VL01L   mod_0  VELO_phi
#  8     hit_threshold     0.0 2011-03-07  -175      VL01L   mod_0  VELO_phi
#  11    hit_threshold     0.0 2011-05-01  -175      VL01L   mod_0  VELO_phi
#  14    hit_threshold     0.0 2011-06-18  -175      VL01L   mod_0  VELO_phi
#  ...             ...     ...        ...   ...        ...     ...       ...
#  7547  hit_threshold   105.0 2016-11-07   750      VL25R  mod_41   VELO_Rx
#  7550  hit_threshold   105.0 2016-11-11   750      VL25R  mod_41   VELO_Rx
#  7553  hit_threshold   105.0 2017-05-21   750      VL25R  mod_41   VELO_Rx
#  7556  hit_threshold   105.0 2017-06-21   750      VL25R  mod_41   VELO_Rx
#  7559  hit_threshold   105.0 2017-07-18   750      VL25R  mod_41   VELO_Rx
#
#       sensor_type sensor_number  channel0  ...  channel2038  channel2039  \
#  2              R            #0      17.0  ...         13.0         12.0
#  5              R            #0      17.0  ...         12.0         12.0
#  8              R            #0      18.0  ...         13.0         13.0
#  11             R            #0      16.0  ...         13.0         14.0
#  14             R            #0      10.0  ...         13.0         13.0
#  ...          ...           ...       ...  ...          ...          ...
#  7547         phi          #105      10.0  ...         10.0          9.0
#  7550         phi          #105       9.0  ...         11.0          9.0
#  7553         phi          #105       9.0  ...         10.0         10.0
#  7556         phi          #105      10.0  ...         11.0          9.0
#  7559         phi          #105       9.0  ...         10.0          9.0
#
#        channel2040  channel2041  channel2042  channel2043  channel2044  \
#  2            12.0         13.0         12.0         13.0         12.0
#  5            12.0         12.0         13.0         13.0         12.0
#  8            13.0         13.0         13.0         13.0         13.0
#  11           14.0         13.0         13.0         13.0         13.0
#  14           13.0         13.0         13.0         13.0         14.0
#  ...           ...          ...          ...          ...          ...
#  7547         10.0         12.0         10.0         12.0         10.0
#  7550         10.0         12.0         11.0         12.0         10.0
#  7553         10.0         12.0         11.0         12.0         10.0
#  7556         10.0         12.0         10.0         12.0         10.0
#  7559         11.0         12.0         10.0         12.0         10.0
#
#        channel2045  channel2046  channel2047
#  2            12.0         12.0         13.0
#  5            13.0         12.0         12.0
#  8            13.0         13.0         13.0
#  11           13.0         14.0         13.0
#  14           14.0         13.0         14.0
#  ...           ...          ...          ...
#  7547         12.0         10.0         12.0
#  7550         12.0         10.0         12.0
#  7553         12.0         10.0         12.0
#  7556         12.0         10.0         12.0
#  7559         12.0         11.0         12.0
#
#  [2520 rows x 2057 columns],
#  'pedestal':           type  sensor   datetime  Zmod slot_label  mod_nr  mod_type  \
#  0     pedestal     0.0 2010-08-16  -175      VL01L   mod_0  VELO_phi
#  3     pedestal     0.0 2010-08-18  -175      VL01L   mod_0  VELO_phi
#  6     pedestal     0.0 2011-03-07  -175      VL01L   mod_0  VELO_phi
#  9     pedestal     0.0 2011-05-01  -175      VL01L   mod_0  VELO_phi
#  12    pedestal     0.0 2011-06-18  -175      VL01L   mod_0  VELO_phi
#  ...        ...     ...        ...   ...        ...     ...       ...
#  7545  pedestal   105.0 2016-11-07   750      VL25R  mod_41   VELO_Rx
#  7548  pedestal   105.0 2016-11-11   750      VL25R  mod_41   VELO_Rx
#  7551  pedestal   105.0 2017-05-21   750      VL25R  mod_41   VELO_Rx
#  7554  pedestal   105.0 2017-06-21   750      VL25R  mod_41   VELO_Rx
#  7557  pedestal   105.0 2017-07-18   750      VL25R  mod_41   VELO_Rx
#
#       sensor_type sensor_number  channel0  ...  channel2038  channel2039  \
#  0              R            #0     515.0  ...        518.0        519.0
#  3              R            #0     515.0  ...        518.0        519.0
#  6              R            #0     516.0  ...        519.0        521.0
#  9              R            #0     516.0  ...        519.0        520.0
#  12             R            #0     516.0  ...        520.0        521.0
#  ...          ...           ...       ...  ...          ...          ...
#  7545         phi          #105     517.0  ...        505.0        507.0
#  7548         phi          #105     518.0  ...        505.0        507.0
#  7551         phi          #105     517.0  ...        504.0        506.0
#  7554         phi          #105     517.0  ...        505.0        506.0
#  7557         phi          #105     517.0  ...        505.0        507.0
#
#        channel2040  channel2041  channel2042  channel2043  channel2044  \
#  0           517.0        519.0        516.0        516.0        518.0
#  3           517.0        519.0        517.0        516.0        518.0
#  6           518.0        520.0        518.0        517.0        520.0
#  9           518.0        519.0        518.0        517.0        519.0
#  12          519.0        520.0        518.0        517.0        520.0
#  ...           ...          ...          ...          ...          ...
#  7545        507.0        509.0        504.0        508.0        508.0
#  7548        507.0        510.0        504.0        509.0        508.0
#  7551        507.0        509.0        503.0        507.0        507.0
#  7554        507.0        509.0        504.0        508.0        507.0
#  7557        507.0        510.0        504.0        508.0        508.0
#
#        channel2045  channel2046  channel2047
#  0           518.0        517.0        516.0
#  3           519.0        517.0        516.0
#  6           520.0        518.0        516.0
#  9           519.0        517.0        516.0
#  12          520.0        518.0        516.0
#  ...           ...          ...          ...
#  7545        506.0        508.0        504.0
#  7548        506.0        509.0        504.0
#  7551        505.0        508.0        503.0
#  7554        506.0        508.0        503.0
#  7557        507.0        508.0        504.0
#
#  [2520 rows x 2057 columns],
#  'low threshold':                type  sensor   datetime  Zmod slot_label  mod_nr  mod_type  \
#  1     low_threshold     0.0 2010-08-16  -175      VL01L   mod_0  VELO_phi
#  4     low_threshold     0.0 2010-08-18  -175      VL01L   mod_0  VELO_phi
#  7     low_threshold     0.0 2011-03-07  -175      VL01L   mod_0  VELO_phi
#  10    low_threshold     0.0 2011-05-01  -175      VL01L   mod_0  VELO_phi
#  13    low_threshold     0.0 2011-06-18  -175      VL01L   mod_0  VELO_phi
#  ...             ...     ...        ...   ...        ...     ...       ...
#  7546  low_threshold   105.0 2016-11-07   750      VL25R  mod_41   VELO_Rx
#  7549  low_threshold   105.0 2016-11-11   750      VL25R  mod_41   VELO_Rx
#  7552  low_threshold   105.0 2017-05-21   750      VL25R  mod_41   VELO_Rx
#  7555  low_threshold   105.0 2017-06-21   750      VL25R  mod_41   VELO_Rx
#  7558  low_threshold   105.0 2017-07-18   750      VL25R  mod_41   VELO_Rx
#
#       sensor_type sensor_number  channel0  ...  channel2038  channel2039  \
#  1              R            #0       7.0  ...          5.0          5.0
#  4              R            #0       7.0  ...          5.0          5.0
#  7              R            #0       7.0  ...          5.0          5.0
#  10             R            #0       7.0  ...          5.0          5.0
#  13             R            #0       4.0  ...          5.0          5.0
#  ...          ...           ...       ...  ...          ...          ...
#  7546         phi          #105       4.0  ...          4.0          4.0
#  7549         phi          #105       4.0  ...          4.0          4.0
#  7552         phi          #105       4.0  ...          4.0          4.0
#  7555         phi          #105       4.0  ...          4.0          4.0
#  7558         phi          #105       4.0  ...          4.0          4.0
#
#        channel2040  channel2041  channel2042  channel2043  channel2044  \
#  1             5.0          5.0          5.0          5.0          5.0
#  4             5.0          5.0          5.0          5.0          5.0
#  7             5.0          5.0          5.0          5.0          5.0
#  10            5.0          5.0          5.0          5.0          5.0
#  13            5.0          5.0          5.0          5.0          5.0
#  ...           ...          ...          ...          ...          ...
#  7546          4.0          5.0          4.0          5.0          4.0
#  7549          4.0          5.0          4.0          5.0          4.0
#  7552          4.0          5.0          4.0          5.0          4.0
#  7555          4.0          5.0          4.0          5.0          4.0
#  7558          4.0          5.0          4.0          5.0          4.0
#
#        channel2045  channel2046  channel2047
#  1             5.0          5.0          5.0
#  4             5.0          5.0          5.0
#  7             5.0          5.0          5.0
#  10            5.0          5.0          5.0
#  13            5.0          5.0          5.0
#  ...           ...          ...          ...
#  7546          5.0          4.0          5.0
#  7549          5.0          4.0          5.0
#  7552          5.0          4.0          5.0
#  7555          5.0          4.0          5.0
#  7558          5.0          4.0          5.0
#
#  [2520 rows x 2057 columns]}

# %%
for key in data:
    data[key] = data[key].drop(['Zmod','slot_label','mod_nr','sensor_number','type','datetime'],axis=1)
    data[key] = {'phi':data[key][(data[key]['mod_type'] =='VELO_phi') & (data[key]['sensor_type'] == 'phi')],\
                    'r_phi':data[key][(data[key]['mod_type'] =='VELO_phi') & (data[key]['sensor_type'] == 'R')],\
                 'r_RX':data[key][(data[key]['mod_type'] =='VELO_Rx')]}
    for typ in data[key]:
        data[key][typ] = data[key][typ].drop(['mod_type','sensor_type'],axis=1)
# Out:
#       sensor  channel0  channel1  channel2  channel3  channel4  channel5  \
# 6842    98.0      10.0      11.0      10.0      11.0      10.0      11.0
# 6845    98.0      10.0      11.0      10.0      11.0      11.0      10.0
# 6848    98.0      10.0      11.0      10.0      11.0      10.0      11.0
# 6851    98.0      10.0      11.0      10.0      11.0      11.0      10.0
# 6854    98.0      10.0      10.0      11.0      10.0      10.0      10.0
# ...      ...       ...       ...       ...       ...       ...       ...
# 7547   105.0      10.0      11.0      11.0      11.0      11.0      11.0
# 7550   105.0       9.0      11.0      11.0      11.0      11.0      11.0
# 7553   105.0       9.0      11.0      11.0      11.0      11.0      11.0
# 7556   105.0      10.0      11.0      11.0      11.0      10.0      11.0
# 7559   105.0       9.0      11.0      10.0      11.0      11.0      11.0
#
#       channel6  channel7  channel8  ...  channel2038  channel2039  \
# 6842      10.0      11.0      10.0  ...         10.0         11.0
# 6845      10.0      11.0      10.0  ...         10.0         11.0
# 6848      10.0      10.0      10.0  ...         10.0         11.0
# 6851      10.0      10.0      10.0  ...          9.0         11.0
# 6854      10.0      10.0      10.0  ...          9.0         12.0
# ...        ...       ...       ...  ...          ...          ...
# 7547      10.0      11.0      10.0  ...         10.0          9.0
# 7550      10.0      11.0      11.0  ...         11.0          9.0
# 7553      10.0      11.0      11.0  ...         10.0         10.0
# 7556      11.0      11.0      11.0  ...         11.0          9.0
# 7559      11.0      11.0      11.0  ...         10.0          9.0
#
#       channel2040  channel2041  channel2042  channel2043  channel2044  \
# 6842          9.0         11.0         10.0         12.0         10.0
# 6845         10.0         12.0         10.0         11.0         10.0
# 6848         10.0         11.0         10.0         11.0         10.0
# 6851          9.0         11.0          9.0         11.0         10.0
# 6854          9.0         11.0          9.0         11.0          9.0
# ...           ...          ...          ...          ...          ...
# 7547         10.0         12.0         10.0         12.0         10.0
# 7550         10.0         12.0         11.0         12.0         10.0
# 7553         10.0         12.0         11.0         12.0         10.0
# 7556         10.0         12.0         10.0         12.0         10.0
# 7559         11.0         12.0         10.0         12.0         10.0
#
#       channel2045  channel2046  channel2047
# 6842         12.0         11.0         11.0
# 6845         11.0         11.0         11.0
# 6848         11.0         11.0         11.0
# 6851         11.0         11.0         11.0
# 6854         11.0         10.0         11.0
# ...           ...          ...          ...
# 7547         12.0         10.0         12.0
# 7550         12.0         10.0         12.0
# 7553         12.0         10.0         12.0
# 7556         12.0         10.0         12.0
# 7559         12.0         11.0         12.0
#
# [120 rows x 2049 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def full_pca(data,percent):
    data = StandardScaler().fit_transform(data)
    data_transponsed = data.transpose()
    pca = PCA(n_components = percent,svd_solver = 'auto')
    result = pca.fit_transform(data_transponsed)
    column_names = [f"Principal component {x+1}" for x in range(len(result[0]))]
    row_names = [f"Channel {x}" for x in range(len(result))]
    return pd.DataFrame(result,columns = column_names,index = row_names)

# %%
procentage_or_num_of_comp = 2

# %%
position = 331
plt.suptitle("PCA results",fontsize=16)
for mod_key in data:
    for sensor_key in data[mod_key]:
        single_data = data[mod_key][sensor_key]
        single_data = {k: v.drop('sensor',axis=1) for k, v in single_data.groupby('sensor')}
        for sensor_data in single_data:
            dataset = single_data[sensor_data]
            dataset_after_pca = full_pca(dataset,procentage_or_num_of_comp)
            plt.scatter(dataset_after_pca.iloc[:,0], dataset_after_pca.iloc[:,1], edgecolor='none', alpha=0.2)
        plt.subplot(position, title=f'{mod_key} - {sensor_key}')
        plt.xlabel('Principal component 1')
        plt.ylabel('Principal component 2')
        position+=1
